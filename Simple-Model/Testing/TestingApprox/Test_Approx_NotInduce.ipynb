# %% [markdown]
# # Testing the Approximate Sampling

# %% [markdown]
# ## Importing the Packages

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams.update(mpl.rcParamsDefault)
mpl.use("pgf")
# %matplotlib inline
plt.plot([1, 2, 3])
mpl.use("pgf")
mpl.rcParams.update(
    {
        "pgf.texsystem": "lualatex",
        "font.family": "serif",
        "text.usetex": True,
        "pgf.rcfonts": False,
        "pgf.preamble": "\n".join(
            [
                r"\usepackage{bm}",
                r"\usepackage{mathtools}",
                r"\usepackage{amsmath}",
                r"\DeclarePairedDelimiter\abs{\lvert}{\rvert}%",
                r"\DeclarePairedDelimiter\norm{\lVert}{\rVert}",
                r"\makeatletter",
                r"\let\oldabs\abs",
                r"\def\abs{\@ifstar{\oldabs}{\oldabs*}}",
                r"\let\oldnorm\norm",
                r"\def\norm{\@ifstar{\oldnorm}{\oldnorm*}}",
                r"\makeatother",
                r"\usepackage[dvipsnames]{xcolor}", 
                r"\definecolor{myred}{RGB}{205, 108, 46}",
            ]
        ),
        "font.serif": ["Computer Modern Roman"],
    }
)

import matplotlib.font_manager
import matplotlib.ticker as mticker
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import Divider, Size, make_axes_locatable
import matplotlib.patches as mpatches
from mpl_toolkits import mplot3d
import matplotlib.cm as cm

import numpy as np
import scipy as sc
import scipy.io as io
from scipy.stats import multivariate_normal
from functools import partial

import jax.numpy as jnp
import jax.scipy as jsc
from jax import grad, jit, vmap, random, lax, value_and_grad, tree_multimap, tree_map

import time

# %%
from jax.config import config
config.update("jax_enable_x64", True)
config.update("jax_debug_nans", True)

# %% [markdown]
# ## Defining SE Covariance

# %%
@jit
def Squared_exp(I, J, Sigma_f, Ell):
  return Sigma_f**2.0*jnp.exp(-(I-J)**2/(2.0*Ell**2))

# %% [markdown]
# ## Creating Test Data

# %%
key = random.PRNGKey(1)
key, *subkeys = random.split(key, 4)

# %%
# Time resolution
time_bin = 0.005

# %% [markdown]
# ### True Filter

# %%
# True variance
sigma_f = 5.0

# True ell
ell_f = 0.5

# Time horizon
fmaxt = 10.0

# Time points for filter
d = np.floor(fmaxt/time_bin).astype(np.int64) 
ftime = np.linspace(0.0, fmaxt, d + 1).reshape((d + 1, 1))

# True covariance matrix
true_cov = Squared_exp(ftime, ftime.T, sigma_f, ell_f)
true_chol = np.linalg.cholesky(true_cov + 1e-6 * np.eye(d + 1))

# Sampling filter
ftrue = true_chol @ random.normal(subkeys[-1], ((d + 1, 1)))

# %%
plt.plot(ftime, ftrue)

# %% [markdown]
# ## Sampling Filter

# %% [markdown]
# ### Add Noise

# %%
# Noise variance
sigma_n = 0.5
noise_vec = random.normal(subkeys[-2], (d + 1, 1)) * sigma_n
yobs = ftrue + noise_vec

# %%
# Number of samples
num_sam = 50

# Window for sampling
lower = int((d + 1) / 6)
upper = int(5 * (d + 1) / 6)
if upper - lower > num_sam:
  indices = np.arange(lower, upper)
  ind_arr = random.choice(subkeys[-2], indices, (num_sam,))
else:
  print('More samples than available in region defined. ' + str(upper - lower) + ' available.')

# %%
fsamp = yobs[ind_arr]
samp_t = ftime[ind_arr,:]

# %%
plt.plot(ftime, yobs)
plt.scatter(samp_t, fsamp, c = 'orange')

# %%
# True posterior
kastn = Squared_exp(ftime, samp_t.T, sigma_f, ell_f)
knn = Squared_exp(samp_t, samp_t.T, sigma_f, ell_f)
kastast = Squared_exp(ftime, ftime, sigma_f, ell_f)

# Posterior mean
post_mean = kastn @ sc.linalg.solve(knn + sigma_n ** 2.0 * np.eye(num_sam) + 1e-6 * np.eye(num_sam), fsamp)

# Posterior variance
post_cov = kastast - kastn @ sc.linalg.solve(knn + sigma_n ** 2.0 * np.eye(num_sam) + 1e-6 * np.eye(num_sam), kastn.T)

trues2 = np.sqrt(np.diag(post_cov))

# %%
post_fill = (post_mean.flatten() - 2 * trues2, post_mean.flatten() + 2 * trues2)
plt.plot(ftime, post_mean)
plt.fill_between(ftime.flatten(), *post_fill, alpha = 0.2)

# %% [markdown]
# ## Approximate Sampling

# %%
@jit
def Solver(Kmm, Diff):
  return jsc.linalg.solve(Kmm, Diff, sym_pos=True, check_finite=True)

# %%
V_Solver = vmap(Solver, in_axes = [None, 0])

# %%
@partial(jit, static_argnums = range(5,8))
def Expected_Term(Sigma_f, Ell, Samp_T, Y_Samples, Sigma_n, Number_F, Num_Base, Num_Sam, F_Time, Subkeys):

  Thetas = random.multivariate_normal(Subkeys[0], jnp.zeros((Number_F, 1, Num_Base)), (1 / (Ell ** 2)) * jnp.eye(Num_Base))

  Taus = random.uniform(Subkeys[1], (Number_F, 1, Num_Base)) * 2.0 * jnp.pi

  Omegas = random.normal(Subkeys[2], (Number_F, Num_Base, 1))

  Constant = Sigma_f * jnp.sqrt(2.0 / Num_Base)

  ST = Samp_T.T
 
  Phi1 = Constant * jnp.cos(F_Time * Thetas + Taus)
  Phi2 = Constant * jnp.cos(Samp_T * Thetas + Taus)

  Knn = Squared_exp(Samp_T, ST, Sigma_f, Ell)
  Knm = Squared_exp(F_Time, ST, Sigma_f, Ell)

  F_Samps = Phi2 @ Omegas

  Vu = V_Solver(Knn + Sigma_n ** 2.0 * jnp.eye(Num_Sam) + 1e-6 * jnp.eye(Num_Sam), Y_Samples - F_Samps \
                                                      - random.normal(Subkeys[4], (Number_F, Num_Sam, 1)) * Sigma_n)

  F_Samples = Phi1 @ Omegas + Knm @ Vu
  
  return F_Samples, jnp.mean(Phi2 @ jnp.transpose(Phi2, (0, 2, 1)), axis = 0)

# %%
test_num_f = 100
test_num_b = 5000
test_key = random.PRNGKey(0)
test_key, *test_subkeys = random.split(test_key, 6)

# %%
pred_horz = 12.0

d2 = np.floor(2 * fmaxt/time_bin).astype(np.int64) 
ftimepred = np.linspace(0.0, pred_horz, d2 + 1).reshape((d2 + 1, 1))

# %%
tst = []
for b in np.linspace(1, 1000, 100).astype(np.int64):
  fsamples, cov_guess = Expected_Term(sigma_f, ell_f, samp_t, fsamp, sigma_n, test_num_f, b, num_sam, ftimepred, test_subkeys)
  # stds = np.std(fsamples, 0)
  # mean = np.mean(fsamples, 0)
  tst.append(np.sqrt(np.mean((cov_guess - Squared_exp(samp_t, samp_t.T, sigma_f, ell_f)) ** 2)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/Testing/TestingApprox/Test_Approx_NotInduce.ipynb Cell 27' in <module>
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/Testing/TestingApprox/Test_Approx_NotInduce.ipynb#ch0000026vscode-remote?line=0'>1</a> tst = []
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/Testing/TestingApprox/Test_Approx_NotInduce.ipynb#ch0000026vscode-remote?line=1'>2</a> for b in np.linspace(1, 1000, 100).astype(np.int64):
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/Testing/TestingApprox/Test_Approx_NotInduce.ipynb#ch0000026vscode-remote?line=2'>3</a>   fsamples, cov_guess = Expected_Term(sigma_f, ell_f, samp_t, fsamp, sigma_n, test_num_f, b, num_sam, ftimepred, test_subkeys)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/Testing/TestingApprox/Test_Approx_NotInduce.ipynb#ch0000026vscode-remote?line=3'>4</a>   # stds = np.std(fsamples, 0)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/Testing/TestingApprox/Test_Approx_NotInduce.ipynb#ch0000026vscode-remote?line=4'>5</a>   # mean = np.mean(fsamples, 0)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/Testing/TestingApprox/Test_Approx_NotInduce.ipynb#ch0000026vscode-remote?line=5'>6</a>   tst.append(np.sqrt(np.mean((cov_guess - Squared_exp(samp_t, samp_t.T, sigma_f, ell_f)) ** 2)))
#
#     [... skipping hidden 1 frame]
#
# File ~/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/api.py:427, in _cpp_jit.<locals>.cache_miss(*args, **kwargs)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/api.py?line=424'>425</a>   _check_arg(arg)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/api.py?line=425'>426</a> flat_fun, out_tree = flatten_fun(closed_fun, in_tree)
# --> <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/api.py?line=426'>427</a> out_flat = xla.xla_call(
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/api.py?line=427'>428</a>     flat_fun, *args_flat,
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/api.py?line=428'>429</a>     device=device, backend=backend, name=flat_fun.__name__,
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/api.py?line=429'>430</a>     donated_invars=donated_invars, inline=inline)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/api.py?line=430'>431</a> out_pytree_def = out_tree()
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/api.py?line=431'>432</a> out = tree_unflatten(out_pytree_def, out_flat)
#
# File ~/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/core.py:1690, in CallPrimitive.bind(self, fun, *args, **params)
#    <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/core.py?line=1688'>1689</a> def bind(self, fun, *args, **params):
# -> <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/core.py?line=1689'>1690</a>   return call_bind(self, fun, *args, **params)
#
# File ~/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/core.py:1702, in call_bind(primitive, fun, *args, **params)
#    <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/core.py?line=1698'>1699</a> fun, env_trace_todo = process_env_traces_call(
#    <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/core.py?line=1699'>1700</a>     fun, primitive, top_trace and top_trace.level, tuple(params.items()))
#    <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/core.py?line=1700'>1701</a> tracers = map(top_trace.full_raise, args)
# -> <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/core.py?line=1701'>1702</a> outs = top_trace.process_call(primitive, fun, tracers, params)
#    <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/core.py?line=1702'>1703</a> return map(full_lower, apply_todos(env_trace_todo(), outs))
#
# File ~/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/core.py:601, in EvalTrace.process_call(self, primitive, f, tracers, params)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/core.py?line=599'>600</a> def process_call(self, primitive, f, tracers, params):
# --> <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/core.py?line=600'>601</a>   return primitive.impl(f, *tracers, **params)
#
# File ~/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py:142, in _xla_call_impl(***failed resolving arguments***)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=138'>139</a> def _xla_call_impl(fun: lu.WrappedFun, *args, device, backend, name,
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=139'>140</a>                    donated_invars, inline):
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=140'>141</a>   del inline  # Only used at tracing time
# --> <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=141'>142</a>   compiled_fun = _xla_callable(fun, device, backend, name, donated_invars,
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=142'>143</a>                                *unsafe_map(arg_spec, args))
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=143'>144</a>   try:
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=144'>145</a>     out = compiled_fun(*args)
#
# File ~/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/linear_util.py:272, in cache.<locals>.memoized_fun(fun, *args)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/linear_util.py?line=269'>270</a>   fun.populate_stores(stores)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/linear_util.py?line=270'>271</a> else:
# --> <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/linear_util.py?line=271'>272</a>   ans = call(fun, *args)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/linear_util.py?line=272'>273</a>   cache[key] = (ans, fun.stores)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/linear_util.py?line=274'>275</a> thread_local.most_recent_entry = weakref.ref(ans)
#
# File ~/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py:169, in _xla_callable_uncached(fun, device, backend, name, donated_invars, *arg_specs)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=166'>167</a> def _xla_callable_uncached(fun: lu.WrappedFun, device, backend, name,
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=167'>168</a>                            donated_invars, *arg_specs):
# --> <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=168'>169</a>   return lower_xla_callable(fun, device, backend, name, donated_invars,
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=169'>170</a>                             *arg_specs).compile().unsafe_call
#
# File ~/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py:528, in XlaComputation.compile(self)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=524'>525</a>     self._executable = XlaCompiledComputation.from_trivial_jaxpr(
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=525'>526</a>         **self.compile_args)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=526'>527</a>   else:
# --> <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=527'>528</a>     self._executable = XlaCompiledComputation.from_xla_computation(
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=528'>529</a>         self.name, self._hlo, **self.compile_args)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=530'>531</a> return self._executable
#
# File ~/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py:614, in XlaCompiledComputation.from_xla_computation(name, xla_computation, nreps, device, backend, tuple_args, in_avals, out_avals, kept_var_idx)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=610'>611</a> options.parameter_is_tupled_arguments = tuple_args
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=611'>612</a> with log_elapsed_time(f"Finished XLA compilation of {name} "
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=612'>613</a>                       "in {elapsed_time} sec"):
# --> <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=613'>614</a>   compiled = compile_or_get_cached(backend, xla_computation, options)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=614'>615</a> buffer_counts = (None if len(out_avals) == 1 else
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=615'>616</a>                  [aval_to_num_buffers(aval) for aval in out_avals])
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=616'>617</a> execute = _execute_compiled if nreps == 1 else _execute_replicated
#
# File ~/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py:583, in compile_or_get_cached(backend, computation, compile_options)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=579'>580</a>   ir_str = (computation if isinstance(computation, str)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=580'>581</a>             else computation.as_hlo_text())
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=581'>582</a>   _dump_ir_to_file(module_name, ir_str)
# --> <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=582'>583</a> return backend_compile(backend, computation, compile_options)
#
# File ~/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/profiler.py:206, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/profiler.py?line=202'>203</a> @wraps(func)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/profiler.py?line=203'>204</a> def wrapper(*args, **kwargs):
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/profiler.py?line=204'>205</a>   with TraceAnnotation(name, **decorator_kwargs):
# --> <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/profiler.py?line=205'>206</a>     return func(*args, **kwargs)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/profiler.py?line=206'>207</a>   return wrapper
#
# File ~/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py:537, in backend_compile(backend, built_c, options)
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=532'>533</a> @profiler.annotate_function
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=533'>534</a> def backend_compile(backend, built_c, options):
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=534'>535</a>   # we use a separate function call to ensure that XLA compilation appears
#     <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=535'>536</a>   # separately in Python profiling results
# --> <a href='file:///home/sgome/Project/Bayesian-Convolutional-Model/Simple-Model/.venv/lib/python3.8/site-packages/jax/_src/dispatch.py?line=536'>537</a>   return backend.compile(built_c, compile_options=options)
#
# KeyboardInterrupt:

# %%
plt.plot(np.linspace(1, 1000, 100).astype(np.int64), tst)

# %%
print(np.sqrt(np.mean((cov_guess - Squared_exp(samp_t, samp_t.T, sigma_f, ell_f)) ** 2)))
# Out:
# 8.940463804422253

# %%
plt.imshow(cov_guess)

# %%
plt.imshow(Squared_exp(samp_t, samp_t.T, sigma_f, ell_f))

# %%
print(cov_guess)
# Out:
# [[ 1.00242252e+00  1.87989729e-02  2.02610385e-03 ...  6.68589411e-01
#    1.90107133e-02 -7.74243051e-03]
#  [ 1.87989729e-02  1.00416817e+00  4.10491678e-03 ...  5.83435301e-03
#    3.55885778e-01  7.85770781e-04]
#  [ 2.02610385e-03  4.10491678e-03  1.00460750e+00 ... -9.25351699e-03
#    1.69807255e-02  5.14091580e-01]
#  ...
#  [ 6.68589411e-01  5.83435301e-03 -9.25351699e-03 ...  1.00649509e+00
#    4.66761213e-03  7.76297839e-03]
#  [ 1.90107133e-02  3.55885778e-01  1.69807255e-02 ...  4.66761213e-03
#    1.00150750e+00  2.38424476e-02]
#  [-7.74243051e-03  7.85770781e-04  5.14091580e-01 ...  7.76297839e-03
#    2.38424476e-02  9.85281940e-01]]

# %%
print(Squared_exp(samp_t, samp_t.T, sigma_f, ell_f))
# Out:
# [[2.50000000e+01 5.36867482e-03 4.17113138e-16 ... 1.66744203e+01
#   4.58108735e-06 1.06969941e-20]
#  [5.36867482e-03 2.50000000e+01 4.38423958e-04 ... 8.86181228e-05
#   8.61130457e+00 1.16921944e-06]
#  [4.17113138e-16 4.38423958e-04 2.50000000e+01 ... 1.02014277e-19
#   1.40110459e-01 1.32027590e+01]
#  ...
#  [1.66744203e+01 8.86181228e-05 1.02014277e-19 ... 2.50000000e+01
#   2.03217484e-08 9.46218330e-25]
#  [4.58108735e-06 8.61130457e+00 1.40110459e-01 ... 2.03217484e-08
#   2.50000000e+01 1.94523172e-03]
#  [1.06969941e-20 1.16921944e-06 1.32027590e+01 ... 9.46218330e-25
#   1.94523172e-03 2.50000000e+01]]

# %% [markdown]
# ## Prediction Posterior

# %%
# True posterior
kastn = Squared_exp(ftimepred, samp_t.T, sigma_f, ell_f)
knn = Squared_exp(samp_t, samp_t.T, sigma_f, ell_f)
kastast = Squared_exp(ftimepred, ftimepred, sigma_f, ell_f)

# Posterior mean
post_mean = kastn @ sc.linalg.solve(knn + sigma_n ** 2.0 * np.eye(num_sam) + 1e-6 * np.eye(num_sam), fsamp)

# Posterior variance
post_cov = kastast - kastn @ sc.linalg.solve(knn + sigma_n ** 2.0 * np.eye(num_sam) + 1e-6 * np.eye(num_sam), kastn.T)

trues2 = np.sqrt(np.diag(post_cov))

# %%
post_fill = (post_mean.flatten() - 2 * trues2, post_mean.flatten() + 2 * trues2)

# %%
fsamples, cov_guess = Expected_Term(sigma_f, ell_f, samp_t, fsamp, sigma_n, test_num_f, test_num_b, num_sam, ftimepred, test_subkeys)

# %%
fsamples.shape
# Out:
# (100, 4001, 1)

# %%
samvar = np.std(fsamples, axis = 0)
samean = np.mean(fsamples, axis = 0)

# %%
for i in range(test_num_f // 2):
  plt.plot(ftimepred, fsamples[2 * i], c = 'b', alpha = 0.5)
pred_fill = (samean.flatten() - 2*samvar.flatten(), samean.flatten() + 2*samvar.flatten())
plt.plot(ftimepred, post_mean)
plt.plot(ftimepred, post_fill[0], c = 'k', linestyle = '--')
plt.plot(ftimepred, post_fill[1], c = 'k', linestyle = '--')
plt.fill_between(ftimepred.flatten(), *pred_fill, alpha = 0.2)
plt.plot(ftimepred, post_mean)
#plt.fill_between(ftime.flatten(), *fill_true, alpha = 0.15, color = 'blue')
# plt.plot(ftime, muast, c = 'k')
# plt.plot(ftime, fill[0], c = 'k', linestyle = '--')
# plt.plot(ftime, fill[1], c = 'k', linestyle = '--')
# fillemp = (mean.flatten() - 2 * stds.flatten(), mean.flatten() + 2 * stds.flatten())
# plt.fill_between(ftime.flatten(), *fillemp, alpha = 0.15, color = 'blue')
# plt.scatter(z_vector, m, zorder = 3, color = 'k', marker = '*', s = 50)
#plt.ylim([-2.75, 2.4])
